# %%
import os

# %%
file_name = "./pitch_example_data"

# %%
with open(file_name) as f:
    messages = [x[1:] for x in f.read().split("\n")]

# %%
orders = {}
# Out:
# ['28800011AAK27GA0000DTS000100SH    0000619200Y',
#  '28800012ABK27GA00000KB001000SSO   0000763800Y',
#  '28800012ABK27GA00000LB001000SSO   0000763600Y',
#  '28800012ABK27GA00000MS001000SSO   0000764800Y',
#  '28800012AAK27GA0000DUS001000SDS   0000549300Y',
#  '28800012AAK27GA0000DVB001000SDS   0000548000Y',
#  '28800012AAK27GA0000DWB000100SPY   0001424100Y',
#  '28800012AAK27GA0000DXS000100SPY   0001426300Y',
#  '28800012AAK27GA0000DYB000100SH    0000618500Y',
#  '28800015AAK27GA0000DZB001000SDS   0000547800Y',
#  '28800075ABK27GA00000NS000100UWM   0000542900Y',
#  '28800075ABK27GA00000OB000100TWM   0000701400Y',
#  '28800075ABK27GA00000PB000100TWM   0000701600Y',
#  '28800075ABK27GA00000QB000100UWM   0000542000Y',
#  '28800075ABK27GA00000RS000100TWM   0000702600Y',
#  '28800075ABK27GA00000SB000100TWM   0000701500Y',
#  '28800136A4K27GA00002RS000100DOG   0000598500Y',
#  '28800137A3K27G6000006S000100DDM   0000802100Y',
#  '28800136A4K27GA00002SS000100DXD   0000501300Y',
# ...
